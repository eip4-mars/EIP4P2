# %% [markdown]
# <a href="https://colab.research.google.com/github/eip4-mars/EIP4P2/blob/master/Session8/Sess8_Drones_SRGAN_UF_4_88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf eva4_lib
# !git clone https://github.com/eip4-mars/eva4_lib.git
# Out:
# Cloning into 'eva4_lib'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 128 (delta 72), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (128/128), 38.96 KiB | 9.74 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
  
import argparse
import os
from math import log10

import pandas as pd
import numpy as np
import torch.optim as optim
import torch.utils.data
import torchvision.utils as utils
from torch.autograd import Variable
from torch.utils.data import DataLoader
from tqdm import tqdm
from IPython.display import clear_output
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchsummary import summary


from eva4_lib.utils import pytorch_ssim
from eva4_lib.utils.srgan_utils import TrainDatasetFromFolder, ValDatasetFromFolder, display_transform
from eva4_lib.utils.srgan_loss import GeneratorLoss
from eva4_lib.models.srgan_model import Generator, Discriminator

import warnings
warnings.filterwarnings("ignore")

# %%
# !nvidia-smi
# Out:
# Sat Oct  3 10:57:42 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# !unzip /content/gdrive/My\ Drive/EVA4P2/Sess2_Drones/Session_2_Dataset.zip
# !mkdir data
# !mkdir data/train
# !mkdir data/val
# !ls -Q Session\ 2\ Dataset/Large\ QuadCopters | head -4821 | xargs -i mv Session\ 2\ Dataset/Large\ QuadCopters/{} /content/data/train/
# !mv Session\ 2\ Dataset/Large\ QuadCopters/* /content/data/val/
# !rm -rf Session\ 2\ Dataset
# !mkdir statistics
# !mkdir chkpt
clear_output()
# !ls /content/data/train|wc -l
# !ls /content/data/val|wc -l
# Out:
# 4811
# 10

# %%
CROP_SIZE =  88 #training images crop size
UPSCALE_FACTOR = 4  #2/4/8
TRAIN_ROOT = '/content/data/train/'
VAL_ROOT = '/content/data/val/'

# %%
train_set = TrainDatasetFromFolder(TRAIN_ROOT, crop_size=CROP_SIZE, upscale_factor=UPSCALE_FACTOR)
val_set = ValDatasetFromFolder(VAL_ROOT, upscale_factor=UPSCALE_FACTOR)
train_loader = DataLoader(dataset=train_set, num_workers=4, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset=val_set, num_workers=4, batch_size=1, shuffle=False)

# Decide which device we want to run on
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
real_batch = next(iter(train_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
netG = Generator(UPSCALE_FACTOR).to(device)
print('# generator parameters:', sum(param.numel() for param in netG.parameters()))
netD = Discriminator().to(device)
print('# discriminator parameters:', sum(param.numel() for param in netD.parameters()))
# Out:
# # generator parameters: 734211
# # discriminator parameters: 5215425

# %%
summary(netG, input_size=(3,22,22))
summary(netD, input_size=(3,88,88))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 22, 22]          15,616
#               ReLU-2           [-1, 64, 22, 22]               0
#             Conv2d-3           [-1, 64, 22, 22]          36,928
#        BatchNorm2d-4           [-1, 64, 22, 22]             128
#               ReLU-5           [-1, 64, 22, 22]               0
#             Conv2d-6           [-1, 64, 22, 22]          36,928
#        BatchNorm2d-7           [-1, 64, 22, 22]             128
#      ResidualBlock-8           [-1, 64, 22, 22]               0
#             Conv2d-9           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-10           [-1, 64, 22, 22]             128
#              ReLU-11           [-1, 64, 22, 22]               0
#            Conv2d-12           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-13           [-1, 64, 22, 22]             128
#     ResidualBlock-14           [-1, 64, 22, 22]               0
#            Conv2d-15           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-16           [-1, 64, 22, 22]             128
#              ReLU-17           [-1, 64, 22, 22]               0
#            Conv2d-18           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-19           [-1, 64, 22, 22]             128
#     ResidualBlock-20           [-1, 64, 22, 22]               0
#            Conv2d-21           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-22           [-1, 64, 22, 22]             128
#              ReLU-23           [-1, 64, 22, 22]               0
#            Conv2d-24           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-25           [-1, 64, 22, 22]             128
#     ResidualBlock-26           [-1, 64, 22, 22]               0
#            Conv2d-27           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-28           [-1, 64, 22, 22]             128
#              ReLU-29           [-1, 64, 22, 22]               0
#            Conv2d-30           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-31           [-1, 64, 22, 22]             128
#     ResidualBlock-32           [-1, 64, 22, 22]               0
#            Conv2d-33           [-1, 64, 22, 22]          36,928
#       BatchNorm2d-34           [-1, 64, 22, 22]             128
#            Conv2d-35          [-1, 256, 22, 22]         147,712
#      PixelShuffle-36           [-1, 64, 44, 44]               0
#              ReLU-37           [-1, 64, 44, 44]               0
#     UpsampleBLock-38           [-1, 64, 44, 44]               0
#            Conv2d-39          [-1, 256, 44, 44]         147,712
#      PixelShuffle-40           [-1, 64, 88, 88]               0
#              ReLU-41           [-1, 64, 88, 88]               0
#     UpsampleBLock-42           [-1, 64, 88, 88]               0
#            Conv2d-43            [-1, 3, 88, 88]          15,555
# ================================================================
# Total params: 734,211
# Trainable params: 734,211
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 27.12
# Params size (MB): 2.80
# Estimated Total Size (MB): 29.92
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 88, 88]           1,792
#               ReLU-2           [-1, 64, 88, 88]               0
#             Conv2d-3           [-1, 64, 44, 44]          36,928
#        BatchNorm2d-4           [-1, 64, 44, 44]             128
#               ReLU-5           [-1, 64, 44, 44]               0
#             Conv2d-6          [-1, 128, 44, 44]          73,856
#        BatchNorm2d-7          [-1, 128, 44, 44]             256
#               ReLU-8          [-1, 128, 44, 44]               0
#             Conv2d-9          [-1, 128, 22, 22]         147,584
#       BatchNorm2d-10          [-1, 128, 22, 22]             256
#              ReLU-11          [-1, 128, 22, 22]               0
#            Conv2d-12          [-1, 256, 22, 22]         295,168
#       BatchNorm2d-13          [-1, 256, 22, 22]             512
#              ReLU-14          [-1, 256, 22, 22]               0
#            Conv2d-15          [-1, 256, 11, 11]         590,080
#       BatchNorm2d-16          [-1, 256, 11, 11]             512
#              ReLU-17          [-1, 256, 11, 11]               0
#            Conv2d-18          [-1, 512, 11, 11]       1,180,160
#       BatchNorm2d-19          [-1, 512, 11, 11]           1,024
#              ReLU-20          [-1, 512, 11, 11]               0
#            Conv2d-21            [-1, 512, 6, 6]       2,359,808
#       BatchNorm2d-22            [-1, 512, 6, 6]           1,024
#              ReLU-23            [-1, 512, 6, 6]               0
# AdaptiveAvgPool2d-24            [-1, 512, 1, 1]               0
#            Conv2d-25           [-1, 1024, 1, 1]         525,312
#              ReLU-26           [-1, 1024, 1, 1]               0
#            Conv2d-27              [-1, 1, 1, 1]           1,025
# ================================================================
# Total params: 5,215,425
# Trainable params: 5,215,425
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.09
# Forward/backward pass size (MB): 22.89
# Params size (MB): 19.90
# Estimated Total Size (MB): 42.88
# ----------------------------------------------------------------

# %%
# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# Initialize BCELoss function
generator_criterion = GeneratorLoss().to(device)

# Create batch of latent vectors that we will use to visualize
#  the progression of the generator
results = {'d_loss': [], 'g_loss': [], 'd_score': [], 'g_score': [], 'psnr': [], 'ssim': []}


# Setup Adam optimizers for both G and D
optimizerD = optim.Adam(netD.parameters()) # , lr=lr, betas=(beta1, 0.999)
optimizerG = optim.Adam(netG.parameters())

# %%
def save_jit(model,save_loc):
    model.to(torch.device('cpu'))
    model.eval()
    traced_model = torch.jit.trace(model,torch.randn(1,1,88,88))
    traced_model.save(save_loc)
    files.download(save_loc)

# %%
# Training Loop
START_EPOCH = 1
NUM_EPOCHS  = 50
print("Starting Training Loop...")
# For each epoch
for epoch in range(START_EPOCH, NUM_EPOCHS+START_EPOCH):
    # For each batch in the dataloader    
    train_bar = tqdm(train_loader)
    running_results = {'batch_sizes': 0, 'd_loss': 0, 'g_loss': 0, 'd_score': 0, 'g_score': 0}

    netG.train()
    netD.train()
    for data, target in train_bar:
        g_update_first = True
        batch_size = data.size(0)
        running_results['batch_sizes'] += batch_size

        ############################
        # (1) Update D network: maximize D(x)-1-D(G(z))
        ###########################
        real_img = Variable(target)
        if torch.cuda.is_available():
            real_img = real_img.cuda()
        z = Variable(data)
        if torch.cuda.is_available():
            z = z.cuda()
        fake_img = netG(z)

        netD.zero_grad()
        real_out = netD(real_img).mean()
        fake_out = netD(fake_img).mean()
        d_loss = 1 - real_out + fake_out
        d_loss.backward(retain_graph=True)
        optimizerD.step()

        ############################
        # (2) Update G network: minimize 1-D(G(z)) + Perception Loss + Image Loss + TV Loss
        ###########################
        netG.zero_grad()
        ############################################################
        ## The two lines below are added to prevent runetime error! ##
        fake_img = netG(z)
        fake_out = netD(fake_img).mean()
        ############################################################
        g_loss = generator_criterion(fake_out, fake_img, real_img)
        g_loss.backward()
        
        # fake_img = netG(z)
        # fake_out = netD(fake_img).mean()
        
        
        optimizerG.step()

        # loss for current batch before optimization 
        running_results['g_loss'] += g_loss.item() * batch_size
        running_results['d_loss'] += d_loss.item() * batch_size
        running_results['d_score'] += real_out.item() * batch_size
        running_results['g_score'] += fake_out.item() * batch_size

        train_bar.set_description(desc='[%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f' % (
            epoch, NUM_EPOCHS, running_results['d_loss'] / running_results['batch_sizes'],
            running_results['g_loss'] / running_results['batch_sizes'],
            running_results['d_score'] / running_results['batch_sizes'],
            running_results['g_score'] / running_results['batch_sizes']))

    netG.eval()
    out_path = 'training_results/SRF_' + str(UPSCALE_FACTOR) + '/'
    if not os.path.exists(out_path):
        os.makedirs(out_path)
    
    with torch.no_grad():
        val_bar = tqdm(val_loader)
        valing_results = {'mse': 0, 'ssims': 0, 'psnr': 0, 'ssim': 0, 'batch_sizes': 0}
        val_images = []
        index = 0
        for val_lr, val_hr_restore, val_hr in val_bar:
            index += 1
            batch_size = val_lr.size(0)
            valing_results['batch_sizes'] += batch_size
            lr = val_lr
            hr = val_hr
            if torch.cuda.is_available():
                lr = lr.cuda()
                hr = hr.cuda()
            sr = netG(lr)
    
            batch_mse = ((sr - hr) ** 2).data.mean()
            valing_results['mse'] += batch_mse * batch_size
            batch_ssim = pytorch_ssim.ssim(sr, hr).item()
            valing_results['ssims'] += batch_ssim * batch_size
            valing_results['psnr'] = 10 * log10((hr.max()**2) / (valing_results['mse'] / valing_results['batch_sizes']))
            valing_results['ssim'] = valing_results['ssims'] / valing_results['batch_sizes']
            val_bar.set_description(
                desc='[converting LR images to SR images] PSNR: %.4f dB SSIM: %.4f' % (
                    valing_results['psnr'], valing_results['ssim']))

            val_images.extend(
                [display_transform()(val_hr_restore.squeeze(0)), display_transform()(hr.data.cpu().squeeze(0)),
                    display_transform()(sr.data.cpu().squeeze(0))])
        val_images = torch.stack(val_images)
        val_images = torch.chunk(val_images, val_images.size(0) // 15)
        val_save_bar = tqdm(val_images, desc='[saving training results]')
        index = 1
        for image in val_save_bar:
            image = utils.make_grid(image, nrow=3, padding=5)
            utils.save_image(image, out_path + 'UF4_epoch_%d_index_%d.png' % (epoch, index), padding=5)
            index += 1

    # save model parameters
    # save loss\scores\psnr\ssim
    results['d_loss'].append(running_results['d_loss'] / running_results['batch_sizes'])
    results['g_loss'].append(running_results['g_loss'] / running_results['batch_sizes'])
    results['d_score'].append(running_results['d_score'] / running_results['batch_sizes'])
    results['g_score'].append(running_results['g_score'] / running_results['batch_sizes'])
    results['psnr'].append(valing_results['psnr'])
    results['ssim'].append(valing_results['ssim'])

    if epoch % 10 == 0 or epoch == 1 or epoch == NUM_EPOCHS:
        torch.save(netG.state_dict(), 'chkpt/netG_epoch_%d_%d.pth' % (UPSCALE_FACTOR, epoch))
        torch.save(netD.state_dict(), 'chkpt/netD_epoch_%d_%d.pth' % (UPSCALE_FACTOR, epoch))
        out_path = 'statistics/'
        data_frame = pd.DataFrame(
            data={'Loss_D': results['d_loss'], 'Loss_G': results['g_loss'], 'Score_D': results['d_score'],
                    'Score_G': results['g_score'], 'PSNR': results['psnr'], 'SSIM': results['ssim']},
            index=range(1, epoch + 1))
        data_frame.to_csv(out_path + 'srf_' + str(UPSCALE_FACTOR) + '_train_results.csv', index_label='Epoch')
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]
# Starting Training Loop...
# [1/50] Loss_D: 0.8807 Loss_G: 0.0235 D(x): 0.3604 D(G(z)): 0.2256: 100%|██████████| 151/151 [01:14<00:00,  2.03it/s]
# [converting LR images to SR images] PSNR: 22.2744 dB SSIM: 0.8223: 100%|██████████| 10/10 [00:03<00:00,  3.20it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [2/50] Loss_D: 0.9942 Loss_G: 0.0128 D(x): 0.7362 D(G(z)): 0.7290: 100%|██████████| 151/151 [01:11<00:00,  2.12it/s]
# [converting LR images to SR images] PSNR: 19.3036 dB SSIM: 0.7946: 100%|██████████| 10/10 [00:03<00:00,  3.25it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [3/50] Loss_D: 0.9979 Loss_G: 0.0107 D(x): 0.7930 D(G(z)): 0.7899: 100%|██████████| 151/151 [01:11<00:00,  2.12it/s]
# [converting LR images to SR images] PSNR: 23.5054 dB SSIM: 0.8619: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# [4/50] Loss_D: 1.0048 Loss_G: 0.0097 D(x): 0.7570 D(G(z)): 0.7622: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 27.0814 dB SSIM: 0.8778: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [5/50] Loss_D: 1.0015 Loss_G: 0.0092 D(x): 0.7834 D(G(z)): 0.7842: 100%|██████████| 151/151 [01:11<00:00,  2.12it/s]
# [converting LR images to SR images] PSNR: 26.5551 dB SSIM: 0.8665: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [6/50] Loss_D: 1.0021 Loss_G: 0.0087 D(x): 0.7498 D(G(z)): 0.7510: 100%|██████████| 151/151 [01:13<00:00,  2.05it/s]
# [converting LR images to SR images] PSNR: 26.8664 dB SSIM: 0.8817: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [7/50] Loss_D: 1.0012 Loss_G: 0.0083 D(x): 0.8633 D(G(z)): 0.8656: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 24.7109 dB SSIM: 0.8774: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# [8/50] Loss_D: 1.0000 Loss_G: 0.0078 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 26.3379 dB SSIM: 0.8708: 100%|██████████| 10/10 [00:03<00:00,  3.25it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# [9/50] Loss_D: 1.0000 Loss_G: 0.0080 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 28.2455 dB SSIM: 0.8849: 100%|██████████| 10/10 [00:03<00:00,  3.23it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [10/50] Loss_D: 1.0000 Loss_G: 0.0076 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.15it/s]
# [converting LR images to SR images] PSNR: 26.9234 dB SSIM: 0.8891: 100%|██████████| 10/10 [00:03<00:00,  3.22it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [11/50] Loss_D: 1.0000 Loss_G: 0.0073 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.19it/s]
# [converting LR images to SR images] PSNR: 25.5302 dB SSIM: 0.8854: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# [12/50] Loss_D: 1.0000 Loss_G: 0.0076 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:11<00:00,  2.12it/s]
# [converting LR images to SR images] PSNR: 23.0835 dB SSIM: 0.8864: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# [13/50] Loss_D: 1.0000 Loss_G: 0.0069 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:11<00:00,  2.11it/s]
# [converting LR images to SR images] PSNR: 28.1791 dB SSIM: 0.8864: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [14/50] Loss_D: 1.0000 Loss_G: 0.0073 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 28.1217 dB SSIM: 0.8890: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [15/50] Loss_D: 1.0000 Loss_G: 0.0068 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 26.1221 dB SSIM: 0.8891: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [16/50] Loss_D: 1.0000 Loss_G: 0.0067 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.15it/s]
# [converting LR images to SR images] PSNR: 26.2008 dB SSIM: 0.8800: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [17/50] Loss_D: 1.0000 Loss_G: 0.0067 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]
# [converting LR images to SR images] PSNR: 27.6093 dB SSIM: 0.8923: 100%|██████████| 10/10 [00:03<00:00,  3.27it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [18/50] Loss_D: 1.0000 Loss_G: 0.0065 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 28.2254 dB SSIM: 0.8983: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [19/50] Loss_D: 1.0000 Loss_G: 0.0065 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]
# [converting LR images to SR images] PSNR: 28.8130 dB SSIM: 0.8987: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [20/50] Loss_D: 1.0000 Loss_G: 0.0065 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.15it/s]
# [converting LR images to SR images] PSNR: 27.1542 dB SSIM: 0.8948: 100%|██████████| 10/10 [00:02<00:00,  3.33it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [21/50] Loss_D: 1.0000 Loss_G: 0.0062 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]
# [converting LR images to SR images] PSNR: 27.8142 dB SSIM: 0.8933: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [22/50] Loss_D: 1.0000 Loss_G: 0.0063 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 29.4183 dB SSIM: 0.9006: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [23/50] Loss_D: 1.0000 Loss_G: 0.0062 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 28.9051 dB SSIM: 0.8982: 100%|██████████| 10/10 [00:03<00:00,  3.27it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [24/50] Loss_D: 1.0000 Loss_G: 0.0062 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 29.3798 dB SSIM: 0.9001: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [25/50] Loss_D: 1.0000 Loss_G: 0.0061 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 29.3612 dB SSIM: 0.9002: 100%|██████████| 10/10 [00:03<00:00,  3.26it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [26/50] Loss_D: 1.0000 Loss_G: 0.0059 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 29.1103 dB SSIM: 0.9024: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [27/50] Loss_D: 1.0000 Loss_G: 0.0059 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]
# [converting LR images to SR images] PSNR: 29.4376 dB SSIM: 0.8977: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [28/50] Loss_D: 1.0000 Loss_G: 0.0058 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 29.3481 dB SSIM: 0.8997: 100%|██████████| 10/10 [00:03<00:00,  3.33it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [29/50] Loss_D: 1.0000 Loss_G: 0.0058 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.13it/s]
# [converting LR images to SR images] PSNR: 29.3079 dB SSIM: 0.9042: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [30/50] Loss_D: 1.0000 Loss_G: 0.0057 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:08<00:00,  2.19it/s]
# [converting LR images to SR images] PSNR: 29.5205 dB SSIM: 0.9037: 100%|██████████| 10/10 [00:02<00:00,  3.34it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [31/50] Loss_D: 1.0000 Loss_G: 0.0057 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 28.8931 dB SSIM: 0.9015: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [32/50] Loss_D: 1.0000 Loss_G: 0.0056 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 29.0238 dB SSIM: 0.9033: 100%|██████████| 10/10 [00:03<00:00,  3.26it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [33/50] Loss_D: 1.0000 Loss_G: 0.0056 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 29.0836 dB SSIM: 0.9049: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [34/50] Loss_D: 1.0000 Loss_G: 0.0056 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 21.1468 dB SSIM: 0.7999: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [35/50] Loss_D: 1.0000 Loss_G: 0.0055 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]
# [converting LR images to SR images] PSNR: 29.0688 dB SSIM: 0.9074: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# [36/50] Loss_D: 1.0000 Loss_G: 0.0054 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.15it/s]
# [converting LR images to SR images] PSNR: 28.8131 dB SSIM: 0.9051: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.06it/s]
# [37/50] Loss_D: 1.0000 Loss_G: 0.0054 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:11<00:00,  2.13it/s]
# [converting LR images to SR images] PSNR: 29.5800 dB SSIM: 0.9024: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [38/50] Loss_D: 1.0000 Loss_G: 0.0053 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 29.5659 dB SSIM: 0.9064: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# [39/50] Loss_D: 1.0000 Loss_G: 0.0053 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 29.1689 dB SSIM: 0.9026: 100%|██████████| 10/10 [00:03<00:00,  3.27it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [40/50] Loss_D: 1.0000 Loss_G: 0.0053 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.15it/s]
# [converting LR images to SR images] PSNR: 29.0917 dB SSIM: 0.9013: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [41/50] Loss_D: 1.0000 Loss_G: 0.0053 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 29.8910 dB SSIM: 0.9036: 100%|██████████| 10/10 [00:03<00:00,  3.30it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [42/50] Loss_D: 1.0000 Loss_G: 0.0052 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 28.9790 dB SSIM: 0.8997: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# [43/50] Loss_D: 1.0000 Loss_G: 0.0053 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:08<00:00,  2.20it/s]
# [converting LR images to SR images] PSNR: 29.4625 dB SSIM: 0.9074: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [44/50] Loss_D: 1.0000 Loss_G: 0.0052 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 29.3688 dB SSIM: 0.9048: 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [45/50] Loss_D: 1.0000 Loss_G: 0.0051 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.16it/s]
# [converting LR images to SR images] PSNR: 29.6651 dB SSIM: 0.9045: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [46/50] Loss_D: 1.0000 Loss_G: 0.0052 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:11<00:00,  2.11it/s]
# [converting LR images to SR images] PSNR: 29.7444 dB SSIM: 0.9040: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# [47/50] Loss_D: 1.0000 Loss_G: 0.0051 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.15it/s]
# [converting LR images to SR images] PSNR: 28.7092 dB SSIM: 0.9018: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [48/50] Loss_D: 1.0000 Loss_G: 0.0051 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:10<00:00,  2.14it/s]
# [converting LR images to SR images] PSNR: 29.2388 dB SSIM: 0.9047: 100%|██████████| 10/10 [00:03<00:00,  3.27it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# [49/50] Loss_D: 1.0000 Loss_G: 0.0051 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]
# [converting LR images to SR images] PSNR: 28.5481 dB SSIM: 0.9070: 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# [50/50] Loss_D: 1.0000 Loss_G: 0.0051 D(x): 1.0000 D(G(z)): 1.0000: 100%|██████████| 151/151 [01:09<00:00,  2.17it/s]
# [converting LR images to SR images] PSNR: 30.0188 dB SSIM: 0.9076: 100%|██████████| 10/10 [00:03<00:00,  3.24it/s]
# [saving training results]: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]

# %%
# SV_LOC = 'DCGAN_cars.pt'
# save_jit(netG,SV_LOC)

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(results['g_loss'],label="G_loss")
plt.plot(results['d_loss'],label="D_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("SSIM")
plt.plot(results['ssim'],label="G_loss")
plt.xlabel("Epochs")
plt.ylabel("SSIM")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("PSNR")
plt.plot(results['psnr'],label="G_loss")
plt.xlabel("Epochs")
plt.ylabel("PSNR")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
torch.save(netD, 'SRGAN_Drone_NetD.pth')
torch.save(netG, 'SRGAN_Drone_NetG.pth')
# Out:
# Mounted at /content/gdrive

# %%
###  convert model to Onnx runtime

x = torch.randn(1, 3, 400, 400, requires_grad=True).to(device)
torch_out = netG(x)

batch_size = 1
torch.onnx.export(netG,               # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "SRGAN_Drone_NetG.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable lenght axes
                                'output' : {0 : 'batch_size'}},
                  example_outputs = torch.randn(1,3,256,256))


torch_out1 = netD(x)
torch.onnx.export(netD,               # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "SRGAN_Drone_NetD.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable lenght axes
                                'output' : {0 : 'batch_size'}},
                  example_outputs = torch.randn(1,1,1,1))

# !cp SRGAN_Drone* /content/gdrive/My\ Drive/EVA4P2/Sess8/

# %%
# !zip Uf4_88.zip /content/training_results/SRF_4/*

# %%
# !zip -r sess8_data.zip /content/data/

# %%
# !pip install onnx onnxruntime
# Out:
# Collecting onnx
#   Downloading https://files.pythonhosted.org/packages/36/ee/bc7bc88fc8449266add978627e90c363069211584b937fd867b0ccc59f09/onnx-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.4MB)
#      |████████████████████████████████| 7.4MB 5.2MB/s
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/25/13/30b82810390591378ceef51cb80c16e56b6868875a5fd2794391132b68b5/onnxruntime-1.5.1-cp36-cp36m-manylinux2014_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 55.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from onnx) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from onnx) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx) (3.7.4.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from onnx) (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->onnx) (50.3.0)
# Installing collected packages: onnx, onnxruntime
# Successfully installed onnx-1.7.0 onnxruntime-1.5.1

# %%
import onnx

onnx_model = onnx.load("/content/SRGAN_Drone_NetG.onnx")
onnx.checker.check_model(onnx_model)

# %%
def denorm_numpy(x):
    x_norm = (x - x.min()) / (x.max() - x.min())
    return x_norm

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# %%
from PIL import Image
im = Image.open("/content/drones-256x256.jpg").resize((400,400))
im

np_im_in = np.array(im).astype(np.float32)/255
plt.imshow(np_im_in)
np_im = np.moveaxis(np_im_in, 2 ,0)
np_im = np.expand_dims(np_im, 0)

# %%
import onnxruntime

ort_session = onnxruntime.InferenceSession("SRGAN_Drone_NetG.onnx")
ort_inputs = {ort_session.get_inputs()[0].name: np_im}
ort_outs = ort_session.run(None, ort_inputs)[0]

#out = denorm_numpy(ort_outs[0])
out = np.moveaxis(ort_outs[0], 0, 2)
plt.figure(figsize=(16, 20))
plt.subplot(1, 2, 1)
plt.imshow(np_im_in)
plt.subplot(1, 2, 2)
plt.imshow(out)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from torchvision.transforms import Compose, RandomCrop, ToTensor, ToPILImage, CenterCrop, Resize
im = Image.open("/content/large_Quadcopter_256x256.jpg").convert('RGB')

def display_transform():
    return Compose([
        Resize(400),
        CenterCrop(400),
        ToTensor()
    ])

im_t = display_transform()(im).unsqueeze(0).to(device)
im_t.shape
out_t = netG(im_t)

# %%
out_np = out_t.squeeze().detach().cpu().numpy()
out = np.moveaxis(out_np, 0, 2)
plt.imshow(out)
